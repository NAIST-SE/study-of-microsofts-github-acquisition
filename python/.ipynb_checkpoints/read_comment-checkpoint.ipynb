# %%
import pandas as pd

# %%
df = pd.read_csv('responses.csv')

# %%
df
# Out:
#               Timestamp  \
# 0    6/29/2018 15:49:39
# 1    6/29/2018 16:42:15
# 2    6/29/2018 16:43:24
# 3    6/29/2018 16:44:37
# 4    6/29/2018 22:01:21
# 5     6/30/2018 3:10:57
# 6     6/30/2018 8:57:00
# 7     7/1/2018 10:53:55
# 8     7/1/2018 17:12:37
# 9     7/2/2018 11:51:43
# 10    7/2/2018 12:17:32
# 11    7/2/2018 15:17:17
# 12    7/2/2018 15:20:15
# 13    7/2/2018 17:57:31
# 14    7/2/2018 18:30:23
# 15    7/2/2018 19:16:59
# 16    7/2/2018 19:51:44
# 17    7/2/2018 20:18:22
# 18    7/2/2018 20:39:39
# 19    7/2/2018 22:11:47
# 20     7/3/2018 0:16:19
# 21     7/3/2018 0:24:08
# 22     7/3/2018 1:11:18
# 23     7/3/2018 3:18:20
# 24    7/3/2018 13:13:04
# 25    7/3/2018 14:18:24
# 26    7/3/2018 15:15:56
# 27    7/3/2018 16:07:42
# 28    7/3/2018 16:08:47
# 29    7/3/2018 17:16:17
# ..                  ...
# 189   7/10/2018 4:36:30
# 190   7/10/2018 4:55:13
# 191   7/10/2018 5:45:27
# 192   7/10/2018 5:57:31
# 193   7/10/2018 5:58:03
# 194   7/10/2018 6:00:39
# ...

# %%
for i in range(len(df.columns)):
    print(i, df.columns[i])
# Out:
# 0 Timestamp
# 1 Which of the roles best describe your main activities within the Linux (distributions or kernel) or BSD?
# 2 Are you a fan of GitHub?
# 3 GitHub appeals to you as it grants access to over 27 million users in this community. If no opinion, select 0.
# 4 GitHub has a set of useful functions (e.g., GitHub Page, Project Management) that every developer will benefit. If no opinion, select 0.
# 5 GitHub does not implement my preferred functions or is missing other functions that I need as a developer. If no opinion, select 0.
# 6 The GitHub platform is superior compared to similar platforms. If no opinion, select 0.
# 7 Which do you think the acquisition will be beneficial or detrimental to any of the projects that you contribute towards? If no opinion, select 0.
# 8 Do you agree that the acquisition will trigger even more expansion of Free and Open Source contributors in GitHub? If no opinion, select 0.
# ...

# %%
columns = 23

# %%
df.columns[columns]
# Out:
# ' If you have any further comments, please feel free to add here (Optional).'

# %%
question = dict(df.iloc[:,13].value_counts())

# %%
question
# Out:
# {"A Platform to develop OpenSource software cannot be controlled by King of closed source software. It's a contradiction.": 1,
#  "FreeBSD doesn't use GitHub as its primary source anyway.": 1,
#  'GitHub was already a proprietary platform, and continues to be a proprietary platform. Its sole advantage is network effects: most users are already on GitHub and used to GitHub.': 1,
#  "GitHub was closed-source either way, Microsoft acquiring it doesn't change much. (Yet.)": 1,
#  "Github has been core to projects I work on, including Chef and Samba. Moving would be awkward: but Microsoft could very easily destroy the trust critical to these projects, much as Sourceforge ruined trust in their repositories by poisoning the idle Windows GIMP project with adware. Trust in Microsoft's business practices is low, for strong historical reason, and it will take a long time to earn that trust.": 1,
# ...

# %%
for q in question:
    p = q.replace('\n','<br>')
    print(f"<tr><td>{p}</td></tr>")
# Out:
# <tr><td>Practically speaking, nothing has changed yet. We are not even talking about predictions, but about "gut feelings".</td></tr>
# <tr><td>A Platform to develop OpenSource software cannot be controlled by King of closed source software. It's a contradiction.</td></tr>
# <tr><td>It's quite hard for me to trust Microsoft, they're probably still planning to EEE stuff - even a "harmless" tiger raised in captivity will still bite. </td></tr>
# <tr><td>Their terrible workplace history is far more of an issue than their ownership and  competent HR department could only be an improvement.</td></tr>
# <tr><td>i'm preparing to leave github with my personal projects before microsoft takes over control to a personal gitea instance!</td></tr>
# <tr><td>Github is great and has done a lot for the free software movement, but there are technically superior alternatives that are free software now, while github is propietary.</td></tr>
# ...

# %%
comment = '''Moved to Gitea long before MS acquired GitHub
I still don't know exactly why Microsoft bought out GitHub, but they need to proceed very very carefully.
For now, unless many other projects move fast (see last comment), I would stay with GitHub, but I am afraid of slowly typical Microsoft integrations, OneDrive, Skype, merge of GitHub and Microsoft account and such things. Would not surprise me but kills the whole idea of FOSS. I think the main reason why great open source related project fail, after big companies buy then, is that a large commercial company, which earn money the opposite way than FOSS related projects try, lack the needed feeling and motivation and relationship to/with the community to be able to bring it forward the right way. FOSS <> proprietary for me is simply an opposite approach. This of course cannot be tied to single people within e.g. Microsoft, but I think the company as a whole will slowly change GitHub in a way, that drives FOSS developers away, just because the idea of what is good and beneficial is simply a different one.
It would be a good idea to have a similar survey regarding "normal" open-source projects hosted on GitHub.
GitHub hurts open development by providing nonfree issue tracking, and rate limiting API access to those features therefore incurring vendor lock-in. To contribute to a GitHub project the contributors are forced to make a GitHub account and have to agree to a GitHub TOS rather than just the project's. I feel the situation will only get worse regarding terms issues with Microsoft management and usability wise the platform will further degrade judging by what happened to past Microsoft acquisitions such as Skype or Mojang.
I feel that Microsoft did a good move and I hope it's a good news for the Open Source ecosystem
So Linux Torvalds the father of linux sold out to Microsoft, and practically works for RedHat exclusively ... I am expecting Microsoft to get control of RedHat and linux kernel development ... in other words Microsoft will end up owning linux. Then, there will only be MAC osx to turn too ... for the time being.
Think like this: 
1. Millions of people offers they labors for free, the hosting of this labor have sale it for a big amount of money to a company. Where's suppose to go the benefit ?
2. What is going to be the benefit of Microsoft in spending such a lot of money for such a platform containing millions of projects that should at the end stays available for free.
Your survey is strongly biased twards a positive feeling abpout github. It's not neutral.
I feel sad about that notice
Your question that has the answers "my primary project uses GH"/"some of the projects have moved away"/"all projects never used it" does not match reality. For example, my real primary project is self-hosted CVS (although I do mirror it on GH). I see you need it to show the different next page, but as-is it's not suitable.
There's a Debian Debconf talk about being able to save / export comments an improved github alike platform. This would ease migrating from github to other platforms if it got implemented as an standard.
Microsoft is like a turd that just wont flush. It seems like they're on the most subtle embrace, extend, extinguish plan after fading to irrelevance. It seems that most are either unaware of Microsofts antics from the past or just fickle about it (ooh freebies) which is sad. I hope Microsoft would just die and go away.
Please consider adding "Do you know the event ?" as a question, because I don't. And that may affect the survey results.
git is git. The git SaaS mostly doesn't matter. 

Also, now "Microsoft has ALL the code". This includes github's commercial clients. This is similar to Amazon having most of the world's server code.
Microsoft does not abide by GNU/Linux philosophies, while Github is heavily intertwined with GNU/Linux philosophies.
I am leaving github because of Microsoft's history of intentionally squashing competing technologies. I cannot support unethical companies.
I've seen a few of the open source hardliner projects move away from GitHub or issues opened on projects that they should move away from GitHub.
I don't see anything wrong with buying Github by Microsoft. For example, we use Skype so far and we will continue to use it until it suits our needs, or until we do something relatively convenient for us.
Today we need more than ever FREEDOM. We can have in a commercial world, we have had in the past in the USA, not in the URSS! But we need to know and understand and defend freedom.

Today and not since today our freedom is getting smaller and smaller from the hardware (UEFI (in)secure-boot etc) to services (how many people instead of have a local maildir sync-ed, for instance, only live on webmails?) to the society in general.
the "Which statement best describes your current situation with any of your contributed projects?" question did not provide for my answer - the project I use most is not on Github, but others I do activity work on are on github and have not moved away
I think the main avantage of gihub is the size of the account pools so it lowers small contribution by lot of people because they have previously an account. It will not be lost by the acquisition.
In my opinion, the goal of microsoft is to provide an automatic deployment to azure. So it's more a bad news to proprietary service like heroku.
it would be great when you release the results as open data for the research community to work with
I could not answer question "Which statement best describes your current situation with any of your contributed projects?" as my answer would be: The projects that I contribute to the most is currently not using GitHub, some projects that I contribute to use GitHub.
Your final question on page 2 needs to be completely redesigned. It is a mandatory question but there are other answers besides "everything uses Github", "nothing has ever used Github", and "one project I contribute to has left Github".

You never define what you mean by "Linux distributions". None of the major Linux distributions use Github directly for everything, but there are many projects packaged by Linux distributions that do use Github.

It feels like you haven't given enough thought about why people have their opinion of the Microsoft acquisition. Some people think Microsoft is the Evil Empire, others think that Microsoft is just another tech company and generally isn't evil these days. That is a big split in the open source community.

There is a huge irony with some open source people being upset at the Github thing when Github isn't even open source at all.
monopoly
GitHub is not the "silver bullet": some of the most successful projects in the world don't even use GitHub - or never used. That said, it's very sad for the OSS community that a company like Microsoft, that since its inception was an enemy of Open Source, acquired GitHub - they don't sell (to me) the idea that they are now a different company. They will have to do more to show so. So far they have done nothing compared to what they have arguably taken.
The formatting and numbering of this survey is very confusing. "No opinion" should be a checkbox, not a "0" on the same numerical scale, to reflect that it does not fit in the numbering.
I have removed all my github projects and will not use it in the future completely due to the acquisition.
As far as I am concerned this is the end of GitHub.
Cloud data never belongs to the user, but always to the cloud provider.
Many team members are not concerned about the use of Github, and the convenience of the features on Github are useful. Visibility of the project (example Mapserver) is very important to some team leaders, and there is no replacement. We at OSGeo dot org have already built our own git server, and it is popular in our group.. the content of the projects is perfectly mirrored, but the tickets and PR history does not port. Some people have found tools to migrate away from Github, but it has not happened in general. The opinions about this are very divided, with strong feelings on different sides.'''

# %%
for c in comment.split('\n'):
    print(f"<tr><td>{c}</td></tr>")
# Out:
# <tr><td>Moved to Gitea long before MS acquired GitHub</td></tr>
# <tr><td>I still don't know exactly why Microsoft bought out GitHub, but they need to proceed very very carefully.</td></tr>
# ...
