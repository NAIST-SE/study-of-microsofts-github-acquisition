# %%
import pandas as pd

# %%
df_mail = pd.read_csv('ack_mail.csv')

# %%
df_mail
# Out:
#    Linux distributions mail status
# 0               Debian        send
# 1               Fedora        send
# 2                 LXLE        send
# 3                 ROSA        send
# 4            DragonFly        send
# 5            Calculate        send
# 6         OpenMandriva        send
# 7               IPFire        send
# 8               SliTaz        send
# 9               NetBSD        send
# 10                Uruk        send
# 11                CRUX        send
# 12               heads        send
# 13          Debian Edu        send
# 14              Endian        send
# 15               OSGeo        send
# 16             LuninuX        send
# 17              Whonix        send
# 18              APODIO        send
# 19       Rocks Cluster        send
# 20               Clear        send
# 21               Lunar        send
# 22          Frugalware        send
# 23           GoboLinux        send
# 24               MirOS        send
# 25         Super Grub2        send
# ...

# %%
for index, row in df_mail.iterrows():
    print(row['Linux distributions'])
    if index % 6 == 0:
        print()
# Out:
# Debian 0
# Fedora 1
# LXLE 2
# ROSA 3
# DragonFly 4
# Calculate 5
# OpenMandriva 6
# IPFire 7
# SliTaz 8
# NetBSD 9
# Uruk 10
# CRUX 11
# heads 12
# Debian Edu 13
# Endian 14
# OSGeo 15
# LuninuX 16
# Whonix 17
# APODIO 18
# Rocks Cluster 19
# Clear 20
# Lunar 21
# Frugalware 22
# GoboLinux 23
# MirOS 24
# Super Grub2 25
# Bio-Linux 26
# GuixSD 27
# Rescatux 28
# gNewSense 29
# Exherbo 30
# Thinstation 31
# Vine 32
# BSDRP 33
# OLPC 34
# T2 35
# Grml 36
# Swecha 37
