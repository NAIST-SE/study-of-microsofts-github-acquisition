# %%
import pandas as pd

# %%
df_mail = pd.read_csv('ack_mail.csv')

# %%
df_mail
# Out:
#    Linux distributions mail status
# 0               Debian        send
# 1               Fedora        send
# 2                 LXLE        send
# 3                 ROSA        send
# 4            DragonFly        send
# 5            Calculate        send
# 6         OpenMandriva        send
# 7               IPFire        send
# 8               SliTaz        send
# 9               NetBSD        send
# 10                Uruk        send
# 11                CRUX        send
# 12               heads        send
# 13          Debian Edu        send
# 14              Endian        send
# 15               OSGeo        send
# 16             LuninuX        send
# 17              Whonix        send
# 18              APODIO        send
# 19       Rocks Cluster        send
# 20               Clear        send
# 21               Lunar        send
# 22          Frugalware        send
# 23           GoboLinux        send
# 24               MirOS        send
# 25         Super Grub2        send
# 26           Bio-Linux        send
# 27              GuixSD        send
# 28            Rescatux        send
# 29           gNewSense        send
# 30             Exherbo        send
# 31         Thinstation        send
# 32                Vine        send
# 33               BSDRP        send
# 34                OLPC        send
# 35                  T2        send
# 36                Grml        send
# 37              Swecha        send

# %%
print('<tr>',end="")
for index, row in df_mail.iterrows():
    name = row["Linux distributions"]
    if index % 6 == 0 and index != 0:
        print('</tr>\n<tr>',end="")
    print("<td>"+name+"</td>",end=" ")
    # print(f"<td>{row['Linux distributions']}</td>",end=" ")
print('\n</tr>',end="")
# Out:
# <tr><td>Debian</td> <td>Fedora</td> <td>LXLE</td> <td>ROSA</td> <td>DragonFly</td> <td>Calculate</td> </tr>
# <tr><td>OpenMandriva</td> <td>IPFire</td> <td>SliTaz</td> <td>NetBSD</td> <td>Uruk</td> <td>CRUX</td> </tr>
# <tr><td>heads</td> <td>Debian Edu</td> <td>Endian</td> <td>OSGeo</td> <td>LuninuX</td> <td>Whonix</td> </tr>
# <tr><td>APODIO</td> <td>Rocks Cluster</td> <td>Clear</td> <td>Lunar</td> <td>Frugalware</td> <td>GoboLinux</td> </tr>
# <tr><td>MirOS</td> <td>Super Grub2</td> <td>Bio-Linux</td> <td>GuixSD</td> <td>Rescatux</td> <td>gNewSense</td> </tr>
# <tr><td>Exherbo</td> <td>Thinstation</td> <td>Vine</td> <td>BSDRP</td> <td>OLPC</td> <td>T2</td> </tr>
# <tr><td>Grml</td> <td>Swecha</td>
# </tr>

# %%
df_forums = pd.read_csv('ack_forum.csv')

# %%
df_forums
# Out:
#     Linux distributions                                        post status
# 0                  Mint                                             banned
# 1               Manjaro  https://forum.manjaro.org/t/research-survey-im...
# 2                Debian                                            deleted
# 3                 Solus  https://solus-project.com/forums/viewtopic.php...
# 4              Antergos  https://forum.antergos.com/topic/10226/researc...
# 5              openSUSE                                            deleted
# 6              MX Linux                                            deleted
# 7                 Zorin                                            deleted
# 8                  Arch                                             banned
# 9               ReactOS  https://www.reactos.org/forum/viewtopic.php?f=...
# 10                 Lite  https://www.linuxliteos.com/forums/off-topic/r...
# 11                Puppy  http://www.murga-linux.com/puppy/viewtopic.php...
# 12              FreeBSD  https://forums.freebsd.org/threads/impact-of-m...
# 13          SparkyLinux  https://sparkylinux.org/forum/index.php/topic,...
# 14            Slackware  https://www.linuxquestions.org/questions/showt...
# 15              Xubuntu                                            deleted
# 16               Devuan  https://dev1galaxy.org/viewtopic.php?pid=10590...
# 17                Bodhi  https://www.linuxquestions.org/questions/showt...
# 18               Gentoo  https://forums.gentoo.org/viewtopic-p-8236548....
# 19              Kubuntu                                            deleted
# 20              Sabayon  https://forum.sabayon.org/viewtopic.php?f=3&t=...
# 21              KNOPPIX                                            deleted
# 22              4MLinux  https://www.linuxquestions.org/questions/showt...
# 23            Tiny Core  http://forum.tinycorelinux.net/index.php/topic...
# 24              ClearOS  https://www.clearos.com/clearfoundation/social...
# 25             GhostBSD  https://forums.ghostbsd.org/viewtopic.php?f=62...
# 26                NixOS  https://groups.google.com/forum/#!topic/nix-de...
# 27        Ubuntu Studio  https://ubuntuforums.org/showthread.php?t=2395...
# 28                NuTyX     https://forums.nutyx.org/index.php?topic=294.0
# 29               wattOS                                            deleted
# ..                  ...                                                ...
# 82              TurnKey  https://www.turnkeylinux.org/forum/general/tue...
# 83               DietPi  https://dietpi.com/phpbb/viewtopic.php?f=9&t=4171
# 84              KANOTIX  http://www.kanotix.com/index.php?name=PNphpBB2...
# 85             Cucumber  https://www.linuxquestions.org/questions/showt...
# 86             Linspire  http://linspire.boards.net/thread/50/survey-im...
# 87          AsteriskNOW  https://community.asterisk.org/t/survey-impact...
# 88                 RISC                                            deleted
# 89           CloudReady  https://neverware.zendesk.com/hc/en-us/communi...
# 90             Rebellin  https://therebellin.com/questions/question/imp...
# 91              RaspBSD  https://forums.freebsd.org/threads/impact-of-m...
# 92           Springdale  https://groups.google.com/forum/#!topic/spring...
# 93          Securepoint                                            deleted
# 94                  PLD  http://forum.pld-linux.org/viewtopic.php?p=388...
# 95           SME Server  https://forums.contribs.org/index.php?topic=53...
# 96                Swift  https://groups.google.com/forum/?fromgroups#!t...
# 97          TalkingArch                                             banned
# 98          NexentaStor  https://community.nexenta.com/s/question/0D50P...
# 99                  SMS  https://sms.it-ccs.com/forum/viewtopic.php?p=4...
# 100               Ulteo  https://groups.google.com/forum/#!topic/ulteo-...
# 101             Volumio  https://volumio.org/forum/impact-microsoft-acq...
# 102               SuliX  http://www.sulix.hu/forum/sulixerver-jellemzoi...
# 103        Webconverger  https://groups.google.com/forum/#!topic/webc-u...
# 104                DRBL  https://sourceforge.net/p/drbl/discussion/Open...
# 105             Dragora  https://www.linuxquestions.org/questions/showt...
# 106             UBports  https://forums.ubports.com/topic/1399/survey-i...
# 107        Liquid Lemur                                            deleted
# 108                 AIO  https://paul.is-a-geek.org/aio-srt/community-s...
# 109          SuperGamer                                            deleted
# 110               Namib  https://forum.namiblinux.org/t/survey-impact-o...
# 111              Obarun  https://forum.obarun.org/viewtopic.php?pid=251...
#
# [112 rows x 2 columns]

# %%
import re
pattern = re.compile("http*")
pattern.search("https://www.reactos.org/forum")
# Out:
# <_sre.SRE_Match object; span=(0, 4), match='http'>

# %%
for index, row in df_forum.iterrows():
    print(index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2a7eb9dfcc03> in <module>()
# ----> 1 for index, row in df_forum.iterrows():
#       2     print(index)
#
# NameError: name 'df_forum' is not defined
