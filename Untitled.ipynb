# %%
import pandas as pd

# %%
df = pd.read_csv('response.csv')

# %%
df
# Out:
#               Timestamp  \
# 0    6/29/2018 15:49:39
# 1    6/29/2018 16:42:15
# 2    6/29/2018 16:43:24
# 3    6/29/2018 16:44:37
# 4    6/29/2018 22:01:21
# 5     6/30/2018 3:10:57
# 6     6/30/2018 8:57:00
# 7     7/1/2018 10:53:55
# 8     7/1/2018 17:12:37
# 9     7/2/2018 11:51:43
# 10    7/2/2018 12:17:32
# 11    7/2/2018 15:17:17
# 12    7/2/2018 15:20:15
# 13    7/2/2018 17:57:31
# 14    7/2/2018 18:30:23
# 15    7/2/2018 19:16:59
# 16    7/2/2018 19:51:44
# 17    7/2/2018 20:18:22
# 18    7/2/2018 20:39:39
# 19    7/2/2018 22:11:47
# 20     7/3/2018 0:16:19
# 21     7/3/2018 0:24:08
# 22     7/3/2018 1:11:18
# 23     7/3/2018 3:18:20
# 24    7/3/2018 13:13:04
# 25    7/3/2018 14:18:24
# 26    7/3/2018 15:15:56
# 27    7/3/2018 16:07:42
# 28    7/3/2018 16:08:47
# 29    7/3/2018 17:16:17
# ..                  ...
# 178   7/9/2018 22:43:22
# 179   7/10/2018 0:44:04
# 180   7/10/2018 1:17:32
# 181   7/10/2018 1:48:57
# 182   7/10/2018 1:51:43
# 183   7/10/2018 1:52:19
# ...

# %%
columns = 1

# %%
question = dict(df[df.columns[columns]].value_counts())

# %%
# pie chart/bar chart
for q in question:
    print('{', end='')
    print(f"name: '{q}', y: {question[q]}",end="")
    print('},')
# Out:
# {name: 'Casual contributor', y: 119},
# {name: 'Core contributor', y: 35},
# {name: 'Project manager/project leader', y: 23},
# {name: 'Project manager/project leader, Core contributor', y: 11},
# {name: 'Project manager/project leader, Core contributor, Casual contributor', y: 4},
# {name: 'User', y: 4},
# {name: 'Project manager/project leader, Casual contributor', y: 2},
# {name: 'Core contributor, Casual contributor', y: 2},
# {name: 'administrator, integrator, user', y: 1},
# {name: 'Tester', y: 1},
# {name: 'I use it for my own computing/donate to projects who develop my distro.', y: 1},
# {name: 'I don't use Linux?', y: 1},
# {name: 'None ', y: 1},
# {name: 'Casual contributor, Third party software developer', y: 1},
# {name: 'Casual contributor, Independent open source developer', y: 1},
# {name: 'Long long time user.', y: 1},

# %%
for q in question:
    print(f"[{q},{question[q]}],")
# Out:
# [4,54],
# [0,45],
# [5,42],
# [3,35],
# [2,17],
# [1,15],
